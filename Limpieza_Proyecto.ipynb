# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **Contexto de la base de datos**
# La medición de la satisfacción de los pasajeros permite a las aerolíneas identificar los factores que más influyen en la experiencia de vuelo, como la puntualidad, el trato del personal, la comodidad de los asientos, la calidad de los alimentos, el entretenimiento a bordo o la eficiencia en el manejo del equipaje. A partir de esta información, las compañías pueden diseñar estrategias más efectivas para mejorar la calidad del servicio, optimizar los procesos operativos y ofrecer una experiencia más coherente con las expectativas del mercado actual.

# %% [markdown]
# # **Descripción general del contenido.**

# %% [markdown]
# La base de datos analizada contiene información detallada sobre la experiencia y satisfacción de pasajeros que viajan en una aerolínea comercial. En ella se combinan datos demográficos, características del viaje, evaluaciones de distintos aspectos del servicio y variables relacionadas con el rendimiento operativo de los vuelos. En conjunto, esta información permite realizar un análisis integral del comportamiento del cliente y de los factores que determinan su nivel de satisfacción general.

# %% [markdown]
# #Cargamos el dataframe sucio

# %%
import pandas as pd
df_sucio = pd.read_csv('/content/drive/MyDrive/df_sucio.csv')
df_sucio
# Out:
#         Unnamed: 0        id  Gender      Customer Type   Age  \
# 0              0.0   70172.0    Male     Loyal Customer  13.0
# 1              1.0    5047.0    Male  disloyal Customer  25.0
# 2              2.0  110028.0  Female                NaN  26.0
# 3              3.0   24026.0  Female     Loyal Customer   NaN
# 4              4.0  119299.0    Male     Loyal Customer  61.0
# ...            ...       ...     ...                ...   ...
# 122176     42836.0  100151.0  Female     Loyal Customer  51.0
# 122177     88812.0   59120.0    Male     Loyal Customer  14.0
# 122178     56378.0   82656.0  Female     Loyal Customer  46.0
# 122179    103464.0   88676.0    Male     Loyal Customer  26.0
# 122180     23773.0   60920.0    Male  disloyal Customer  39.0
#
#          Type of Travel     Class  Flight Distance  Inflight wifi service  \
# 0       Personal Travel       NaN            460.0                    3.0
# ...

# %% [markdown]
# #Eliminamos la columna Unnamed: 0

# %%
#Eliminamos la columna Unnamed: 0 (ya que solo es un índice)
df_sucio=df_sucio.drop(columns=['Unnamed: 0'])
df_sucio
# Out:
#               id  Gender      Customer Type   Age   Type of Travel     Class  \
# 0        70172.0    Male     Loyal Customer  13.0  Personal Travel       NaN
# 1         5047.0    Male  disloyal Customer  25.0  Business travel  Business
# 2       110028.0  Female                NaN  26.0  Business travel  Business
# 3        24026.0  Female     Loyal Customer   NaN  Business travel  Business
# 4       119299.0    Male     Loyal Customer  61.0  Business travel  Business
# ...          ...     ...                ...   ...              ...       ...
# 122176  100151.0  Female     Loyal Customer  51.0              bbb  Business
# 122177   59120.0    Male     Loyal Customer  14.0  Personal Travel       Eco
# 122178   82656.0  Female     Loyal Customer  46.0              NaN  Business
# 122179   88676.0    Male     Loyal Customer  26.0  Personal Travel       Eco
# 122180   60920.0    Male  disloyal Customer  39.0  Business travel  Business
#
# ...

# %% [markdown]
# # **Primer análisis**

# %% [markdown]
# En primera instancia se debe analizar con cuántos datos se cuentan, además de que tipo son para poder tomar decisones conforme a las condiciones que se cuentan

# %%
#Por este medio podemos ver cuantos datos se tienen por fila y columna
df_sucio.shape
# Out:
# (122181, 24)

# %%
#Para poder visualizar mejor el tipo de datos con el que se trabaja se necesita observar las columnas del dataframe
df_sucio.columns
# Out:
# Index(['id', 'Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
#Mediante esto podemos visualizar que tipo de dato contiene cada columna
df_sucio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 98665 entries, 0 to 122165
# Data columns (total 24 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   id                                    98665 non-null  object
#  1   Genero                                98665 non-null  object
#  2   Tipo de Cliente                       98665 non-null  object
#  3   Edad                                  98665 non-null  int64
#  4   Tipo de Viaje                         98665 non-null  object
#  5   Clase                                 98665 non-null  object
#  6   Distancia de Vuelo                    98665 non-null  int64
#  7   Servicio de Wifi                      98665 non-null  int64
#  8   Tiempo de Llegada/Salida Conveniente  98665 non-null  int64
#  9   Facilidad de Reservacion en Linea     98665 non-null  int64
#  10  Ubicacion de Puerta                   98665 non-null  int64
# ...

# %%
#Detectamos los valores nulos en cada columna
df_sucio.isnull().sum()
# Out:
# id                                   7242
# Gender                               4887
# Customer Type                        4887
# Age                                  7217
# Type of Travel                       4887
# Class                                4887
# Flight Distance                      4887
# Inflight wifi service                4887
# Departure/Arrival time convenient    4887
# Ease of Online booking               4887
# Gate location                        4887
# Food and drink                       7233
# Online boarding                      4887
# Seat comfort                         4887
# Inflight entertainment               4887
# On-board service                     4887
# Leg room service                     4887
# Baggage handling                     4887
# Checkin service                      4887
# Inflight service                     4887
# Cleanliness                          4887
# Departure Delay in Minutes           4887
# ...

# %% [markdown]
# # **Limpieza por columna**

# %% [markdown]
# ## **1. Columna Id**

# %%
#Detectamos valores nulos
df_sucio['id'].isnull().sum()
# Out:
# np.int64(7242)

# %%
#Reemplazamos valores nulos
df_sucio['id'] = df_sucio['id'].fillna('Sin Id')
df_sucio
# Out:
#               id  Gender      Customer Type   Age   Type of Travel     Class  \
# 0        70172.0    Male     Loyal Customer  13.0  Personal Travel       NaN
# 1         5047.0    Male  disloyal Customer  25.0  Business travel  Business
# 2       110028.0  Female                NaN  26.0  Business travel  Business
# 3        24026.0  Female     Loyal Customer   NaN  Business travel  Business
# 4       119299.0    Male     Loyal Customer  61.0  Business travel  Business
# ...          ...     ...                ...   ...              ...       ...
# 122176  100151.0  Female     Loyal Customer  51.0              bbb  Business
# 122177   59120.0    Male     Loyal Customer  14.0  Personal Travel       Eco
# 122178   82656.0  Female     Loyal Customer  46.0              NaN  Business
# 122179   88676.0    Male     Loyal Customer  26.0  Personal Travel       Eco
# 122180   60920.0    Male  disloyal Customer  39.0  Business travel  Business
#
# ...

# %%
#Observamos cuantos registros duplicados existen en la columna
df_sucio['id'].duplicated().sum()
# Out:
# np.int64(23516)

# %%
df_sucio['id'].value_counts()
# Out:
# id
# Sin Id      7242
# 36078.0        5
# 2996.0         5
# 112550.0       4
# 72784.0        4
#             ...
# 92320.0        1
# 15853.0        1
# 83437.0        1
# 104401.0       1
# 114393.0       1
# Name: count, Length: 98665, dtype: int64

# %%
df_sucio[df_sucio['id'] == 36078]
# Out:
#              id  Gender   Customer Type   Age   Type of Travel Class  \
# 73694   36078.0  Female  Loyal Customer  58.0  Personal Travel   Eco
# 114885  36078.0  Female  Loyal Customer  58.0  Personal Travel   Eco
# 116274  36078.0  Female  Loyal Customer  58.0  Personal Travel   Eco
# 119012  36078.0  Female  Loyal Customer  58.0              NaN   Eco
# 119758  36078.0  Female  Loyal Customer  58.0  Personal Travel   Eco
#
#         Flight Distance  Inflight wifi service  \
# 73694             399.0                    4.0
# 114885            399.0                    4.0
# 116274              NaN                    4.0
# 119012            399.0                    4.0
# 119758            399.0                    4.0
#
#         Departure/Arrival time convenient  Ease of Online booking  ...  \
# 73694                                 3.0                     4.0  ...
# 114885                                3.0                     4.0  ...
# ...

# %% [markdown]
# Ya que identificamos que algunos registros son exactamente iguales podemos eliminarlos sin afectar el contenido

# %%
df_sucio['id'].duplicated().sum()
# Out:
# np.int64(23516)

# %%
#Eliminar duplicados
df_sucio = df_sucio.drop_duplicates(subset='id')
df_sucio
# Out:
#               id  Gender      Customer Type   Age   Type of Travel     Class  \
# 0        70172.0    Male     Loyal Customer  13.0  Personal Travel       NaN
# 1         5047.0    Male  disloyal Customer  25.0  Business travel  Business
# 2       110028.0  Female                NaN  26.0  Business travel  Business
# 3        24026.0  Female     Loyal Customer   NaN  Business travel  Business
# 4       119299.0    Male     Loyal Customer  61.0  Business travel  Business
# ...          ...     ...                ...   ...              ...       ...
# 122096   15853.0  Female     Loyal Customer   NaN  Business travel  Business
# 122128   83437.0  Female  disloyal Customer  23.0  Business travel       Eco
# 122129  104401.0    Male     Loyal Customer  60.0  Business travel  Business
# 122140  114393.0  Female     Loyal Customer  44.0  Business travel  Business
# 122165   55896.0  Female  disloyal Customer  48.0  Business travel  Business
#
# ...

# %%
#Verificamos que no haya más duplicados
df_sucio['id'].duplicated().sum()
# Out:
# np.int64(0)

# %%
df_sucio['id'].value_counts()
# Out:
# id
# 55896.0     1
# 70172.0     1
# 5047.0      1
# 110028.0    1
# 24026.0     1
#            ..
# 83502.0     1
# 98628.0     1
# 51412.0     1
# 34991.0     1
# 65725.0     1
# Name: count, Length: 98665, dtype: int64

# %% [markdown]
# ## **2. Columna Gender**

# %%
#Identificar los valores nulos
df_sucio['Gender'].isnull().sum()
# Out:
# np.int64(3967)

# %%
#Cambiar los NaN por la palabra Sin Género
df_sucio['Gender'] = df_sucio['Gender'].fillna('Sin Género')
# Out:
# /tmp/ipython-input-3417425133.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['Gender'] = df_sucio['Gender'].fillna('Sin Género')

# %%
#Verificamos que no haya valores nulos
df_sucio['Gender'].isnull().sum()
# Out:
# np.int64(0)

# %%
#Visualizamos cuantos datos tenemos en la columna
df_sucio['Gender'].value_counts()
# Out:
# Gender
# Female        47023
# Male          45746
# Sin Género     3967
# bbb            1929
# Name: count, dtype: int64

# %% [markdown]
# Datos atípicos (Cadenas de texto)

# %%
#Observamos que datos contiene la columna
df_sucio['Gender'].unique()
# Out:
# array(['Male', 'Female', 'Sin Género', 'bbb'], dtype=object)

# %% [markdown]
# Debido a que se encontró un dato atípico que es 'bbb' se tiene que corregir

# %%
#Reemplazamos ese dato atípico por otro valor
df_sucio['Gender'] = df_sucio['Gender'].replace('bbb', 'Sin Género')
df_sucio
# Out:
# /tmp/ipython-input-1614268352.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['Gender'] = df_sucio['Gender'].replace('bbb', 'Sin Género')
#               id  Gender      Customer Type   Age   Type of Travel     Class  \
# 0        70172.0    Male     Loyal Customer  13.0  Personal Travel       NaN
# 1         5047.0    Male  disloyal Customer  25.0  Business travel  Business
# 2       110028.0  Female                NaN  26.0  Business travel  Business
# 3        24026.0  Female     Loyal Customer   NaN  Business travel  Business
# 4       119299.0    Male     Loyal Customer  61.0  Business travel  Business
# ...          ...     ...                ...   ...              ...       ...
# ...

# %%
#Comprobamos que no hayan más datos atípicos
df_sucio['Gender'].unique()
# Out:
# array(['Male', 'Female', 'Sin Género'], dtype=object)

# %%
df_sucio['Gender'].value_counts()
# Out:
# Gender
# Female        47023
# Male          45746
# Sin Género     5896
# Name: count, dtype: int64

# %% [markdown]
# ## **3. Columna Customer Type**

# %%
df_sucio.columns
# Out:
# Index(['id', 'Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
#Visualizamos cuantos datos tenemos de cada variable
df_sucio['Customer Type'].value_counts()
# Out:
# Customer Type
# Loyal Customer       77456
# disloyal Customer    17273
# Name: count, dtype: int64

# %%
#Observamos los datos que se encuentran en la columna
df_sucio['Customer Type'].unique()
# Out:
# array(['Loyal Customer', 'disloyal Customer', nan], dtype=object)

# %%
#Identificamos cuantos valores nulos hay
df_sucio['Customer Type'].isnull().sum()
# Out:
# np.int64(3936)

# %%
#Reemplazamos los valores nulos para no afectar al contenido
df_sucio['Customer Type'] = df_sucio['Customer Type'].fillna('Sin Cliente Especifico')
df_sucio
# Out:
# /tmp/ipython-input-1162263454.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['Customer Type'] = df_sucio['Customer Type'].fillna('Sin Cliente Especifico')
#               id  Gender           Customer Type   Age   Type of Travel  \
# 0        70172.0    Male          Loyal Customer  13.0  Personal Travel
# 1         5047.0    Male       disloyal Customer  25.0  Business travel
# 2       110028.0  Female  Sin Cliente Especifico  26.0  Business travel
# 3        24026.0  Female          Loyal Customer   NaN  Business travel
# 4       119299.0    Male          Loyal Customer  61.0  Business travel
# ...          ...     ...                     ...   ...              ...
# ...

# %%
df_sucio['Customer Type'].value_counts()
# Out:
# Customer Type
# Loyal Customer            77456
# disloyal Customer         17273
# Sin Cliente Especifico     3936
# Name: count, dtype: int64

# %% [markdown]
# ## **4. Columna Age**

# %%
#Identificamos los valores nulos
df_sucio['Age'].isnull().sum()
# Out:
# np.int64(5844)

# %%
#Cantidad de datos
df_sucio['Age'].value_counts()
# Out:
# Age
# 39.0    2662
# 25.0    2458
# 40.0    2323
# 44.0    2203
# 41.0    2192
#         ...
# 73.0      42
# 76.0      39
# 79.0      38
# 78.0      33
# 85.0      17
# Name: count, Length: 75, dtype: int64

# %%
#Corregimos los valores NaN reemplzando por la media de los datos de la columna edad
df_sucio['Age'] = df_sucio['Age'].fillna(df_sucio['Age'].mean())
df_sucio
# Out:
# /tmp/ipython-input-3023096898.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['Age'] = df_sucio['Age'].fillna(df_sucio['Age'].mean())
#               id  Gender           Customer Type        Age   Type of Travel  \
# 0        70172.0    Male          Loyal Customer  13.000000  Personal Travel
# 1         5047.0    Male       disloyal Customer  25.000000  Business travel
# 2       110028.0  Female  Sin Cliente Especifico  26.000000  Business travel
# 3        24026.0  Female          Loyal Customer  39.414335  Business travel
# 4       119299.0    Male          Loyal Customer  61.000000  Business travel
# ...          ...     ...                     ...        ...              ...
# ...

# %%
#Convertimos los valores numéricos a tipo entero
df_sucio['Age']=df_sucio['Age'].astype(int)
df_sucio
# Out:
# /tmp/ipython-input-3523648331.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['Age']=df_sucio['Age'].astype(int)
#               id  Gender           Customer Type  Age   Type of Travel  \
# 0        70172.0    Male          Loyal Customer   13  Personal Travel
# 1         5047.0    Male       disloyal Customer   25  Business travel
# 2       110028.0  Female  Sin Cliente Especifico   26  Business travel
# 3        24026.0  Female          Loyal Customer   39  Business travel
# 4       119299.0    Male          Loyal Customer   61  Business travel
# ...          ...     ...                     ...  ...              ...
# 122096   15853.0  Female          Loyal Customer   39  Business travel
# ...

# %% [markdown]
# Verificamos que este adecuadamente

# %%
df_sucio['Age'].value_counts()
# Out:
# Age
# 39    8506
# 25    2458
# 40    2323
# 44    2203
# 41    2192
#       ...
# 73      42
# 76      39
# 79      38
# 78      33
# 85      17
# Name: count, Length: 75, dtype: int64

# %%
df_sucio['Age'].unique()
# Out:
# array([13, 25, 26, 39, 61, 47, 52, 41, 20, 24, 12, 53, 33, 45, 38,  9, 17,
#        43, 58, 23, 49, 36, 22, 31, 15, 35, 67, 37, 40, 34, 50, 29, 54, 21,
#        28, 27, 69, 60, 57, 48, 59, 46, 30, 66, 64, 44, 51, 32, 19, 42, 16,
#        11, 62,  8, 56, 68, 18, 55, 65, 72, 63, 10,  7, 70, 14, 80, 74, 71,
#        85, 76, 77, 75, 73, 79, 78])

# %%
df_sucio['Age'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## **5. Columna Type of Travel**

# %%
#Identificamos la cantidad de valores nulos
df_sucio['Type of Travel'].isnull().sum()
# Out:
# np.int64(3994)

# %%
#observamos que datos tenemos en la columna
df_sucio['Type of Travel'].unique()
# Out:
# array(['Personal Travel', 'Business travel', 'bbb', nan], dtype=object)

# %%
#Cantidad de datos en la columna
df_sucio['Type of Travel'].value_counts()
# Out:
# Type of Travel
# Business travel    63904
# Personal Travel    28883
# bbb                 1884
# Name: count, dtype: int64

# %%
#Reemplazamos los valores nulos para no afectar el contenido
df_sucio['Type of Travel'] = df_sucio['Type of Travel'].fillna('Sin Viaje')
df_sucio
# Out:
# /tmp/ipython-input-3315881470.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['Type of Travel'] = df_sucio['Type of Travel'].fillna('Sin Viaje')
#               id  Gender           Customer Type  Age   Type of Travel  \
# 0        70172.0    Male          Loyal Customer   13  Personal Travel
# 1         5047.0    Male       disloyal Customer   25  Business travel
# 2       110028.0  Female  Sin Cliente Especifico   26  Business travel
# 3        24026.0  Female          Loyal Customer   39  Business travel
# 4       119299.0    Male          Loyal Customer   61  Business travel
# ...          ...     ...                     ...  ...              ...
# 122096   15853.0  Female          Loyal Customer   39  Business travel
# ...

# %%
#Correción de valores atípicos
df_sucio['Type of Travel'] = df_sucio['Type of Travel'].replace('bbb', 'Sin Viaje')
df_sucio
# Out:
# /tmp/ipython-input-2337865713.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['Type of Travel'] = df_sucio['Type of Travel'].replace('bbb', 'Sin Viaje')
#               id  Gender           Customer Type  Age   Type of Travel  \
# 0        70172.0    Male          Loyal Customer   13  Personal Travel
# 1         5047.0    Male       disloyal Customer   25  Business travel
# 2       110028.0  Female  Sin Cliente Especifico   26  Business travel
# 3        24026.0  Female          Loyal Customer   39  Business travel
# 4       119299.0    Male          Loyal Customer   61  Business travel
# ...          ...     ...                     ...  ...              ...
# ...

# %% [markdown]
# Verificar si todo está en orden

# %%
df_sucio['Type of Travel'].value_counts()
# Out:
# Type of Travel
# Business travel    63904
# Personal Travel    28883
# Sin Viaje           5878
# Name: count, dtype: int64

# %% [markdown]
# ## **6. Columna Class**

# %%
#Datos en la columna
df_sucio['Class'].unique()
# Out:
# array([nan, 'Business', 'Eco', 'Eco Plus', 'bbb'], dtype=object)

# %%
#Cantidad de datos en la columna
df_sucio['Class'].value_counts()
# Out:
# Class
# Business    44331
# Eco         41759
# Eco Plus     6713
# bbb          1914
# Name: count, dtype: int64

# %%
#Detectamos los valores nulos
df_sucio['Class'].isnull().sum()
# Out:
# np.int64(3948)

# %%
#Reemplazamos los valores nulos para no afectar el contenido
df_sucio['Class'] = df_sucio['Class'].fillna('Sin Clase')
df_sucio.head(20)
# Out:
# /tmp/ipython-input-2722312778.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['Class'] = df_sucio['Class'].fillna('Sin Clase')
#           id  Gender           Customer Type  Age   Type of Travel      Class  \
# 0    70172.0    Male          Loyal Customer   13  Personal Travel  Sin Clase
# 1     5047.0    Male       disloyal Customer   25  Business travel   Business
# 2   110028.0  Female  Sin Cliente Especifico   26  Business travel   Business
# 3    24026.0  Female          Loyal Customer   39  Business travel   Business
# 4   119299.0    Male          Loyal Customer   61  Business travel   Business
# 5   111157.0  Female          Loyal Customer   39  Personal Travel        Eco
# ...

# %% [markdown]
# Correción de datos atípicos

# %%
#Notamos que hay un texto que no concuerda con la información de la columna
df_sucio['Class'].unique()
# Out:
# array(['Sin Clase', 'Business', 'Eco', 'Eco Plus', 'bbb'], dtype=object)

# %%
#Corrección de datos atípicos
#Se reemplaza por un dato que no afecte al contenido
df_sucio['Class'] = df_sucio['Class'].replace('bbb', 'Sin Clase')
df_sucio
# Out:
# /tmp/ipython-input-515637440.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['Class'] = df_sucio['Class'].replace('bbb', 'Sin Clase')
#               id  Gender           Customer Type  Age   Type of Travel  \
# 0        70172.0    Male          Loyal Customer   13  Personal Travel
# 1         5047.0    Male       disloyal Customer   25  Business travel
# 2       110028.0  Female  Sin Cliente Especifico   26  Business travel
# 3        24026.0  Female          Loyal Customer   39  Business travel
# 4       119299.0    Male          Loyal Customer   61  Business travel
# ...          ...     ...                     ...  ...              ...
# 122096   15853.0  Female          Loyal Customer   39  Business travel
# ...

# %% [markdown]
# Verificamos que esté correctamente

# %%
df_sucio['Class'].unique()
# Out:
# array(['Sin Clase', 'Business', 'Eco', 'Eco Plus'], dtype=object)

# %%
df_sucio['Class'].value_counts()
# Out:
# Class
# Business     44331
# Eco          41759
# Eco Plus      6713
# Sin Clase     5862
# Name: count, dtype: int64

# %%
df_sucio['Class'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## **7. Columna Flight Distance**

# %%
#Cantidad de datos en la columna
df_sucio['Flight Distance'].value_counts()
# Out:
# Flight Distance
# 337.0     597
# 594.0     356
# 404.0     354
# 2475.0    334
# 862.0     332
#          ...
# 1122.0      1
# 155.0       1
# 2547.0      1
# 1393.0      1
# 1317.0      1
# Name: count, Length: 3788, dtype: int64

# %%
#Detección de valores nulos
df_sucio['Flight Distance'].isnull().sum()
# Out:
# np.int64(3965)

# %%
df_sucio['Flight Distance'].median()
# Out:
# 843.0

# %%
#Reemplazamos los valores nulos por la mediana
df_sucio['Flight Distance'] = df_sucio['Flight Distance'].fillna(df_sucio['Flight Distance'].median())
df_sucio
# Out:
# /tmp/ipython-input-3688804409.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['Flight Distance'] = df_sucio['Flight Distance'].fillna(df_sucio['Flight Distance'].median())
#               id  Gender           Customer Type  Age   Type of Travel  \
# 0        70172.0    Male          Loyal Customer   13  Personal Travel
# 1         5047.0    Male       disloyal Customer   25  Business travel
# 2       110028.0  Female  Sin Cliente Especifico   26  Business travel
# 3        24026.0  Female          Loyal Customer   39  Business travel
# 4       119299.0    Male          Loyal Customer   61  Business travel
# ...          ...     ...                     ...  ...              ...
# ...

# %%
#Conversion de tipo de dato de decimal a entero
df_sucio['Flight Distance']=df_sucio['Flight Distance'].astype(int)
df_sucio
# Out:
# /tmp/ipython-input-3204404710.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['Flight Distance']=df_sucio['Flight Distance'].astype(int)
#               id  Gender           Customer Type  Age   Type of Travel  \
# 0        70172.0    Male          Loyal Customer   13  Personal Travel
# 1         5047.0    Male       disloyal Customer   25  Business travel
# 2       110028.0  Female  Sin Cliente Especifico   26  Business travel
# 3        24026.0  Female          Loyal Customer   39  Business travel
# 4       119299.0    Male          Loyal Customer   61  Business travel
# ...          ...     ...                     ...  ...              ...
# 122096   15853.0  Female          Loyal Customer   39  Business travel
# ...

# %% [markdown]
# Validación de que todo está en orden

# %%
df_sucio['Flight Distance'].value_counts()
# Out:
# Flight Distance
# 843     3998
# 337      597
# 594      356
# 404      354
# 2475     334
#         ...
# 1479       1
# 400        1
# 1284       1
# 1267       1
# 1317       1
# Name: count, Length: 3788, dtype: int64

# %%
df_sucio['Flight Distance'].unique()
# Out:
# array([ 460,  235, 1142, ..., 1284, 1267, 1317])

# %%
df_sucio['Flight Distance'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## **8. Columna Inflight wifi service**

# %%
#Detección de valores nulos
df_sucio['Inflight wifi service'].isnull().sum()
# Out:
# np.int64(3946)

# %%
df_sucio['Inflight wifi service'].value_counts()
# Out:
# Inflight wifi service
# 2.0    23590
# 3.0    23534
# 4.0    18005
# 1.0    16318
# 5.0    10443
# 0.0     2829
# Name: count, dtype: int64

# %%
#Reemplazamos los valores nulos por la mediana
df_sucio['Inflight wifi service'] = df_sucio['Inflight wifi service'].fillna(df_sucio['Inflight wifi service'].median())
# Out:
# /tmp/ipython-input-2624133859.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['Inflight wifi service'] = df_sucio['Inflight wifi service'].fillna(df_sucio['Inflight wifi service'].median())

# %%
#Conversión de valores de decimal a entero
df_sucio['Inflight wifi service']=df_sucio['Inflight wifi service'].astype(int)
df_sucio
# Out:
# /tmp/ipython-input-598974063.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['Inflight wifi service']=df_sucio['Inflight wifi service'].astype(int)
#               id  Gender           Customer Type  Age   Type of Travel  \
# 0        70172.0    Male          Loyal Customer   13  Personal Travel
# 1         5047.0    Male       disloyal Customer   25  Business travel
# 2       110028.0  Female  Sin Cliente Especifico   26  Business travel
# 3        24026.0  Female          Loyal Customer   39  Business travel
# 4       119299.0    Male          Loyal Customer   61  Business travel
# ...          ...     ...                     ...  ...              ...
# ...

# %% [markdown]
# Verificación

# %%
df_sucio['Inflight wifi service'].value_counts()
# Out:
# Inflight wifi service
# 3    27480
# 2    23590
# 4    18005
# 1    16318
# 5    10443
# 0     2829
# Name: count, dtype: int64

# %%
df_sucio['Inflight wifi service'].unique()
# Out:
# array([3, 2, 4, 1, 5, 0])

# %%
df_sucio['Inflight wifi service'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## **9. Columna Departure/Arrival time convenient**

# %%
df_sucio['Departure/Arrival time convenient'].value_counts()
# Out:
# Departure/Arrival time convenient
# 4.0    23308
# 5.0    20405
# 3.0    16357
# 2.0    15681
# 1.0    14169
# 0.0     4828
# Name: count, dtype: int64

# %%
#Detección de valores nulos
df_sucio['Departure/Arrival time convenient'].isnull().sum()
# Out:
# np.int64(3917)

# %%
#Reemplazamos los valores nulos por la moda
df_sucio['Departure/Arrival time convenient'] = df_sucio['Departure/Arrival time convenient'].fillna(df_sucio['Departure/Arrival time convenient'].mode()[0])
df_sucio
# Out:
# /tmp/ipython-input-3251320078.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['Departure/Arrival time convenient'] = df_sucio['Departure/Arrival time convenient'].fillna(df_sucio['Departure/Arrival time convenient'].mode()[0])
#               id  Gender           Customer Type  Age   Type of Travel  \
# 0        70172.0    Male          Loyal Customer   13  Personal Travel
# 1         5047.0    Male       disloyal Customer   25  Business travel
# 2       110028.0  Female  Sin Cliente Especifico   26  Business travel
# 3        24026.0  Female          Loyal Customer   39  Business travel
# 4       119299.0    Male          Loyal Customer   61  Business travel
# ...

# %%
#Conversión de valores de decimal a entero
df_sucio['Departure/Arrival time convenient']=df_sucio['Departure/Arrival time convenient'].astype(int)
df_sucio
# Out:
# /tmp/ipython-input-1136585980.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['Departure/Arrival time convenient']=df_sucio['Departure/Arrival time convenient'].astype(int)
#               id  Gender           Customer Type  Age   Type of Travel  \
# 0        70172.0    Male          Loyal Customer   13  Personal Travel
# 1         5047.0    Male       disloyal Customer   25  Business travel
# 2       110028.0  Female  Sin Cliente Especifico   26  Business travel
# 3        24026.0  Female          Loyal Customer   39  Business travel
# 4       119299.0    Male          Loyal Customer   61  Business travel
# ...          ...     ...                     ...  ...              ...
# ...

# %% [markdown]
# Verificación

# %%
df_sucio['Departure/Arrival time convenient'].isnull().sum()
# Out:
# np.int64(0)

# %%
df_sucio['Departure/Arrival time convenient'].value_counts()
# Out:
# Departure/Arrival time convenient
# 4    27225
# 5    20405
# 3    16357
# 2    15681
# 1    14169
# 0     4828
# Name: count, dtype: int64

# %% [markdown]
# # **10. Columna Ease of Online booking**

# %%
#Datos en la columna
df_sucio['Ease of Online booking'].unique()
# Out:
# array([ 3.,  2.,  5.,  4.,  1., nan,  0.])

# %%
#Deteccion de valores nulos
df_sucio['Ease of Online booking'].isnull().sum()
# Out:
# np.int64(3953)

# %%
#Reemplazamos los valores nulos por la moda
df_sucio['Ease of Online booking'] = df_sucio['Ease of Online booking'].fillna(df_sucio['Ease of Online booking'].mode()[0])
# Out:
# /tmp/ipython-input-4102155264.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['Ease of Online booking'] = df_sucio['Ease of Online booking'].fillna(df_sucio['Ease of Online booking'].mode()[0])

# %%
#Conversión de valores de decimal a entero
df_sucio['Ease of Online booking']=df_sucio['Ease of Online booking'].astype(int)
df_sucio
# Out:
# /tmp/ipython-input-3030382738.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['Ease of Online booking']=df_sucio['Ease of Online booking'].astype(int)
#               id  Gender           Customer Type  Age   Type of Travel  \
# 0        70172.0    Male          Loyal Customer   13  Personal Travel
# 1         5047.0    Male       disloyal Customer   25  Business travel
# 2       110028.0  Female  Sin Cliente Especifico   26  Business travel
# 3        24026.0  Female          Loyal Customer   39  Business travel
# 4       119299.0    Male          Loyal Customer   61  Business travel
# ...          ...     ...                     ...  ...              ...
# ...

# %% [markdown]
# Verificación

# %%
df_sucio['Ease of Online booking'].isnull().sum()
# Out:
# np.int64(0)

# %%
#Cantidad de valores
df_sucio['Ease of Online booking'].value_counts()
# Out:
# Ease of Online booking
# 3    26196
# 2    21957
# 4    17839
# 1    15970
# 5    12622
# 0     4081
# Name: count, dtype: int64

# %%
df_sucio.columns
# Out:
# Index(['id', 'Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %% [markdown]
# # **11. Columna Gate location**

# %%
#Datos en la columna
df_sucio['Gate location'].unique()
# Out:
# array([ 1.,  3.,  2.,  5.,  4., nan,  0.])

# %%
#Deteccion de valores nulos
df_sucio['Gate location'].isnull().sum()
# Out:
# np.int64(3950)

# %%
#Cantidad de datos
df_sucio['Gate location'].value_counts()
# Out:
# Gate location
# 3.0    25973
# 4.0    22317
# 2.0    17717
# 1.0    16029
# 5.0    12678
# 0.0        1
# Name: count, dtype: int64

# %%
#Reemplazamos los valores nulos por la moda
df_sucio['Gate location'] = df_sucio['Gate location'].fillna(df_sucio['Gate location'].mode()[0])
# Out:
# /tmp/ipython-input-2349011482.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['Gate location'] = df_sucio['Gate location'].fillna(df_sucio['Gate location'].mode()[0])

# %%
#Conversión de valores de decimal a entero
df_sucio['Gate location']=df_sucio['Gate location'].astype(int)
df_sucio
# Out:
# /tmp/ipython-input-3558066157.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['Gate location']=df_sucio['Gate location'].astype(int)
#               id  Gender           Customer Type  Age   Type of Travel  \
# 0        70172.0    Male          Loyal Customer   13  Personal Travel
# 1         5047.0    Male       disloyal Customer   25  Business travel
# 2       110028.0  Female  Sin Cliente Especifico   26  Business travel
# 3        24026.0  Female          Loyal Customer   39  Business travel
# 4       119299.0    Male          Loyal Customer   61  Business travel
# ...          ...     ...                     ...  ...              ...
# 122096   15853.0  Female          Loyal Customer   39  Business travel
# ...

# %% [markdown]
# Verificación

# %%
df_sucio['Gate location'].isnull().sum()
# Out:
# np.int64(0)

# %%
#Cantidad de valores
df_sucio['Gate location'].value_counts()
# Out:
# Gate location
# 3    29923
# 4    22317
# 2    17717
# 1    16029
# 5    12678
# 0        1
# Name: count, dtype: int64

# %% [markdown]
# # **12. Columna Food and drink**

# %%
#Datos en la columna
df_sucio['Food and drink'].unique()
# Out:
# array([ 5.,  1.,  2.,  4.,  3., nan,  0.])

# %%
#Deteccion de valores nulos
df_sucio['Food and drink'].isnull().sum()
# Out:
# np.int64(5863)

# %%
#Cantidad de datos
df_sucio['Food and drink'].value_counts()
# Out:
# Food and drink
# 4.0    21855
# 5.0    19924
# 3.0    19855
# 2.0    19648
# 1.0    11423
# 0.0       97
# Name: count, dtype: int64

# %%
#Reemplazamos los valores nulos por la moda
df_sucio['Food and drink'] = df_sucio['Food and drink'].fillna(df_sucio['Food and drink'].mode()[0])
# Out:
# /tmp/ipython-input-1384322016.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['Food and drink'] = df_sucio['Food and drink'].fillna(df_sucio['Food and drink'].mode()[0])

# %%
#Conversión de valores de decimal a entero
df_sucio['Food and drink']=df_sucio['Food and drink'].astype(int)
df_sucio
# Out:
# /tmp/ipython-input-2827214700.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['Food and drink']=df_sucio['Food and drink'].astype(int)
#               id  Gender           Customer Type  Age   Type of Travel  \
# 0        70172.0    Male          Loyal Customer   13  Personal Travel
# 1         5047.0    Male       disloyal Customer   25  Business travel
# 2       110028.0  Female  Sin Cliente Especifico   26  Business travel
# 3        24026.0  Female          Loyal Customer   39  Business travel
# 4       119299.0    Male          Loyal Customer   61  Business travel
# ...          ...     ...                     ...  ...              ...
# 122096   15853.0  Female          Loyal Customer   39  Business travel
# ...

# %% [markdown]
# Verificación

# %%
df_sucio['Food and drink'].isnull().sum()
# Out:
# np.int64(0)

# %%
#Cantidad de valores
df_sucio['Food and drink'].value_counts()
# Out:
# Food and drink
# 4    27718
# 5    19924
# 3    19855
# 2    19648
# 1    11423
# 0       97
# Name: count, dtype: int64

# %% [markdown]
# # **13. Columna Online boarding**

# %%
#Datos en la columna
df_sucio['Online boarding'].unique()
# Out:
# array(['3', nan, '2', '5', '1', '4', 'bbb', '0'], dtype=object)

# %%
#Cantidad de datos
df_sucio['Online boarding'].value_counts()
# Out:
# Online boarding
# 4      27531
# 3      19470
# 5      18478
# 2      15628
# 1       9543
# 0       2167
# bbb     1901
# Name: count, dtype: int64

# %%
#Deteeción de valores nulos
df_sucio['Online boarding'].isnull().sum()
# Out:
# np.int64(3947)

# %%
#Corrección de valores atípicos
df_sucio['Online boarding'] = df_sucio['Online boarding'].replace('bbb', df_sucio['Online boarding'].mode()[0])
# Out:
# /tmp/ipython-input-1423938861.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['Online boarding'] = df_sucio['Online boarding'].replace('bbb', df_sucio['Online boarding'].mode()[0])

# %%
#Correción de valores nulos
df_sucio['Online boarding'] = df_sucio['Online boarding'].fillna(df_sucio['Online boarding'].mode()[0])
# Out:
# /tmp/ipython-input-3580738588.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['Online boarding'] = df_sucio['Online boarding'].fillna(df_sucio['Online boarding'].mode()[0])

# %% [markdown]
# Desde el principio notamos que el tipo de dato en la columna es un object, por lo tanto, debemos convertir esos datos a tipo entero

# %%
#Conversión de datos a tipo int
df_sucio['Online boarding']=df_sucio['Online boarding'].astype(int)
df_sucio
# Out:
# /tmp/ipython-input-139230885.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['Online boarding']=df_sucio['Online boarding'].astype(int)
#               id  Gender           Customer Type  Age   Type of Travel  \
# 0        70172.0    Male          Loyal Customer   13  Personal Travel
# 1         5047.0    Male       disloyal Customer   25  Business travel
# 2       110028.0  Female  Sin Cliente Especifico   26  Business travel
# 3        24026.0  Female          Loyal Customer   39  Business travel
# 4       119299.0    Male          Loyal Customer   61  Business travel
# ...          ...     ...                     ...  ...              ...
# 122096   15853.0  Female          Loyal Customer   39  Business travel
# ...

# %% [markdown]
# Verficación

# %%
df_sucio['Online boarding'].isnull().sum()
# Out:
# np.int64(0)

# %%
df_sucio['Online boarding'].unique()
# Out:
# array([3, 4, 2, 5, 1, 0])

# %%
df_sucio['Online boarding'].value_counts()
# Out:
# Online boarding
# 4    33379
# 3    19470
# 5    18478
# 2    15628
# 1     9543
# 0     2167
# Name: count, dtype: int64

# %%
df_sucio.columns
# Out:
# Index(['id', 'Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %% [markdown]
# # **14. Columna Seat comfort**

# %%
#Datos en la columna
df_sucio['Seat comfort'].unique()
# Out:
# array([ 5.,  1.,  2.,  3.,  4., nan,  0.])

# %%
#Cantidad de datos
df_sucio['Seat comfort'].value_counts()
# Out:
# Seat comfort
# 4.0    28938
# 5.0    24106
# 3.0    17049
# 2.0    13562
# 1.0    11060
# 0.0        1
# Name: count, dtype: int64

# %%
#Deteeción de valores nulos
df_sucio['Seat comfort'].isnull().sum()
# Out:
# np.int64(3949)

# %%
#Correción de valores nulos
df_sucio['Seat comfort'] = df_sucio['Seat comfort'].fillna(df_sucio['Seat comfort'].mode()[0])
# Out:
# /tmp/ipython-input-407342809.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['Seat comfort'] = df_sucio['Seat comfort'].fillna(df_sucio['Seat comfort'].mode()[0])

# %%
#Conversión de datos a tipo int
df_sucio['Seat comfort']=df_sucio['Seat comfort'].astype(int)
# Out:
# /tmp/ipython-input-543914434.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['Seat comfort']=df_sucio['Seat comfort'].astype(int)

# %% [markdown]
# Verificación

# %%
df_sucio['Seat comfort'].isnull().sum()
# Out:
# np.int64(0)

# %%
df_sucio['Seat comfort'].unique()
# Out:
# array([5, 1, 2, 3, 4, 0])

# %%
df_sucio['Seat comfort'].value_counts()
# Out:
# Seat comfort
# 4    32887
# 5    24106
# 3    17049
# 2    13562
# 1    11060
# 0        1
# Name: count, dtype: int64

# %% [markdown]
# # **15. Columna Inflight entertainment**

# %%
#Datos en la columna
df_sucio['Inflight entertainment'].unique()
# Out:
# array(['5', '1', '2', '3', nan, '4', 'bbb', '0'], dtype=object)

# %%
#Cantidad de datos
df_sucio['Inflight entertainment'].value_counts()
# Out:
# Inflight entertainment
# 4      26237
# 5      22521
# 3      17084
# 2      15717
# 1      11175
# bbb     1934
# 0         13
# Name: count, dtype: int64

# %%
#Deteeción de valores nulos
df_sucio['Inflight entertainment'].isnull().sum()
# Out:
# np.int64(3984)

# %%
#Corrección de valores atípicos
df_sucio['Inflight entertainment'] = df_sucio['Inflight entertainment'].replace('bbb', df_sucio['Inflight entertainment'].mode()[0])
# Out:
# /tmp/ipython-input-1536314470.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['Inflight entertainment'] = df_sucio['Inflight entertainment'].replace('bbb', df_sucio['Inflight entertainment'].mode()[0])

# %%
#Correción de valores nulos
df_sucio['Inflight entertainment'] = df_sucio['Inflight entertainment'].fillna(df_sucio['Inflight entertainment'].mode()[0])
# Out:
# /tmp/ipython-input-1101092217.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['Inflight entertainment'] = df_sucio['Inflight entertainment'].fillna(df_sucio['Inflight entertainment'].mode()[0])

# %% [markdown]
# Desde el principio notamos que el tipo de dato en la columna es un object, por lo tanto, debemos convertir esos datos a tipo entero

# %%
#Conversión de datos a tipo int
df_sucio['Inflight entertainment']=df_sucio['Inflight entertainment'].astype(int)
# Out:
# /tmp/ipython-input-3541462326.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['Inflight entertainment']=df_sucio['Inflight entertainment'].astype(int)

# %% [markdown]
# Verificación

# %%
df_sucio['Inflight entertainment'].isnull().sum()
# Out:
# np.int64(0)

# %%
df_sucio['Inflight entertainment'].unique()
# Out:
# array([5, 1, 2, 3, 4, 0])

# %%
df_sucio['Inflight entertainment'].value_counts()
# Out:
# Inflight entertainment
# 4    32155
# 5    22521
# 3    17084
# 2    15717
# 1    11175
# 0       13
# Name: count, dtype: int64

# %%
df_sucio.columns
# Out:
# Index(['id', 'Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %% [markdown]
# # **16. Columna On-board service**

# %%
#Datos en la columna
df_sucio['On-board service'].unique()
# Out:
# array(['4', '1', '2', '3', '5', nan, 'bbb', '0'], dtype=object)

# %%
#Datos en la columna
df_sucio['On-board service'].value_counts()
# Out:
# On-board service
# 4      27575
# 5      21149
# 3      20405
# 2      13055
# 1      10588
# bbb     1891
# 0          3
# Name: count, dtype: int64

# %%
#Deteeción de valores nulos
df_sucio['On-board service'].isnull().sum()
# Out:
# np.int64(3999)

# %%
#Corrección de valores atípicos
df_sucio['On-board service'] = df_sucio['On-board service'].replace('bbb', df_sucio['On-board service'].mode()[0])
# Out:
# /tmp/ipython-input-232615564.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['On-board service'] = df_sucio['On-board service'].replace('bbb', df_sucio['On-board service'].mode()[0])

# %%
#Correción de valores nulos
df_sucio['On-board service'] = df_sucio['On-board service'].fillna(df_sucio['On-board service'].mode()[0])
# Out:
# /tmp/ipython-input-733204105.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['On-board service'] = df_sucio['On-board service'].fillna(df_sucio['On-board service'].mode()[0])

# %% [markdown]
# Desde el principio notamos que el tipo de dato en la columna es un object, por lo tanto, debemos convertir esos datos a tipo entero

# %%
#Conversión de datos a tipo int
df_sucio['On-board service']=df_sucio['On-board service'].astype(int)
df_sucio
# Out:
# /tmp/ipython-input-168515410.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['On-board service']=df_sucio['On-board service'].astype(int)
#               id  Gender           Customer Type  Age   Type of Travel  \
# 0        70172.0    Male          Loyal Customer   13  Personal Travel
# 1         5047.0    Male       disloyal Customer   25  Business travel
# 2       110028.0  Female  Sin Cliente Especifico   26  Business travel
# 3        24026.0  Female          Loyal Customer   39  Business travel
# 4       119299.0    Male          Loyal Customer   61  Business travel
# ...          ...     ...                     ...  ...              ...
# 122096   15853.0  Female          Loyal Customer   39  Business travel
# ...

# %% [markdown]
# Verficación

# %%
df_sucio['On-board service'].isnull().sum()
# Out:
# np.int64(0)

# %%
df_sucio['On-board service'].unique()
# Out:
# array([4, 1, 2, 3, 5, 0])

# %%
df_sucio['On-board service'].value_counts()
# Out:
# On-board service
# 4    33465
# 5    21149
# 3    20405
# 2    13055
# 1    10588
# 0        3
# Name: count, dtype: int64

# %%
df_sucio.columns
# Out:
# Index(['id', 'Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %% [markdown]
# # **17. Columna Leg room service**

# %%
#Datos en la columna
df_sucio['Leg room service'].unique()
# Out:
# array([ 3.,  5.,  4.,  2.,  1., nan,  0.])

# %%
#Datos en la columna
df_sucio['Leg room service'].value_counts()
# Out:
# Leg room service
# 4.0    26205
# 5.0    22501
# 3.0    18355
# 2.0    17783
# 1.0     9430
# 0.0      423
# Name: count, dtype: int64

# %%
#Deteeción de valores nulos
df_sucio['Leg room service'].isnull().sum()
# Out:
# np.int64(3968)

# %%
#Correción de valores nulos cambiandolos por el promedio
df_sucio['Leg room service'] = df_sucio['Leg room service'].fillna(df_sucio['Leg room service'].mean())
# Out:
# /tmp/ipython-input-4173451409.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['Leg room service'] = df_sucio['Leg room service'].fillna(df_sucio['Leg room service'].mean())

# %%
#Conversión de datos a tipo int
df_sucio['Leg room service']=df_sucio['Leg room service'].astype(int)
df_sucio
# Out:
# /tmp/ipython-input-1305185804.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['Leg room service']=df_sucio['Leg room service'].astype(int)
#               id  Gender           Customer Type  Age   Type of Travel  \
# 0        70172.0    Male          Loyal Customer   13  Personal Travel
# 1         5047.0    Male       disloyal Customer   25  Business travel
# 2       110028.0  Female  Sin Cliente Especifico   26  Business travel
# 3        24026.0  Female          Loyal Customer   39  Business travel
# 4       119299.0    Male          Loyal Customer   61  Business travel
# ...          ...     ...                     ...  ...              ...
# 122096   15853.0  Female          Loyal Customer   39  Business travel
# ...

# %% [markdown]
# Verficación

# %%
df_sucio['Leg room service'].isnull().sum()
# Out:
# np.int64(0)

# %%
df_sucio['Leg room service'].unique()
# Out:
# array([3, 5, 4, 2, 1, 0])

# %%
df_sucio['Leg room service'].value_counts()
# Out:
# Leg room service
# 4    26205
# 5    22501
# 3    22323
# 2    17783
# 1     9430
# 0      423
# Name: count, dtype: int64

# %%
df_sucio.columns
# Out:
# Index(['id', 'Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %% [markdown]
# # **18. Columna Baggage handling**

# %%
#Datos en la columna
df_sucio['Baggage handling'].unique()
# Out:
# array(['4', '3', nan, '5', '1', '2', 'bbb'], dtype=object)

# %%
#Cantidad de datos en la columna
df_sucio['Baggage handling'].value_counts()
# Out:
# Baggage handling
# 4      33310
# 5      24275
# 3      18491
# 2      10228
# 1       6481
# bbb     1918
# Name: count, dtype: int64

# %%
#Deteeción de valores nulos
df_sucio['Baggage handling'].isnull().sum()
# Out:
# np.int64(3962)

# %%
#Corrección de valores atípicos
df_sucio['Baggage handling'] = df_sucio['Baggage handling'].replace('bbb', "5")
# Out:
# /tmp/ipython-input-2709869722.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['Baggage handling'] = df_sucio['Baggage handling'].replace('bbb', "5")

# %%
#Correción de valores nulos
df_sucio['Baggage handling'] = df_sucio['Baggage handling'].fillna(df_sucio['Baggage handling'].mode()[0])
# Out:
# /tmp/ipython-input-926848762.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['Baggage handling'] = df_sucio['Baggage handling'].fillna(df_sucio['Baggage handling'].mode()[0])

# %% [markdown]
# Desde el principio notamos que el tipo de dato en la columna es un object, por lo tanto, debemos convertir esos datos a tipo entero

# %%
#Conversión de datos a tipo int
df_sucio['Baggage handling']=df_sucio['Baggage handling'].astype(int)
df_sucio
# Out:
# /tmp/ipython-input-1805134344.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['Baggage handling']=df_sucio['Baggage handling'].astype(int)
#               id  Gender           Customer Type  Age   Type of Travel  \
# 0        70172.0    Male          Loyal Customer   13  Personal Travel
# 1         5047.0    Male       disloyal Customer   25  Business travel
# 2       110028.0  Female  Sin Cliente Especifico   26  Business travel
# 3        24026.0  Female          Loyal Customer   39  Business travel
# 4       119299.0    Male          Loyal Customer   61  Business travel
# ...          ...     ...                     ...  ...              ...
# 122096   15853.0  Female          Loyal Customer   39  Business travel
# ...

# %% [markdown]
# Verficación

# %%
df_sucio['Baggage handling'].isnull().sum()
# Out:
# np.int64(0)

# %%
df_sucio['Baggage handling'].unique()
# Out:
# array([4, 3, 5, 1, 2])

# %%
df_sucio['Baggage handling'].value_counts()
# Out:
# Baggage handling
# 4    37272
# 5    26193
# 3    18491
# 2    10228
# 1     6481
# Name: count, dtype: int64

# %%
df_sucio.columns
# Out:
# Index(['id', 'Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %% [markdown]
# # **19. Columna Checkin service**

# %%
#Datos en la columna
df_sucio['Checkin service'].unique()
# Out:
# array([ 4.,  1.,  3., nan,  5.,  2.,  0.])

# %%
#Datos en la columna
df_sucio['Checkin service'].value_counts()
# Out:
# Checkin service
# 4.0    26447
# 3.0    25990
# 5.0    18787
# 2.0    11775
# 1.0    11769
# 0.0        1
# Name: count, dtype: int64

# %%
#Deteeción de valores nulos
df_sucio['Checkin service'].isnull().sum()
# Out:
# np.int64(3896)

# %%
#Correción de valores nulos cambiandolos por el promedio
df_sucio['Checkin service'] = df_sucio['Checkin service'].fillna(df_sucio['Checkin service'].mean())
# Out:
# /tmp/ipython-input-2766039024.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['Checkin service'] = df_sucio['Checkin service'].fillna(df_sucio['Checkin service'].mean())

# %%
#Conversión de datos a tipo int
df_sucio['Checkin service']=df_sucio['Checkin service'].astype(int)
df_sucio
# Out:
# /tmp/ipython-input-2660215386.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['Checkin service']=df_sucio['Checkin service'].astype(int)
#               id  Gender           Customer Type  Age   Type of Travel  \
# 0        70172.0    Male          Loyal Customer   13  Personal Travel
# 1         5047.0    Male       disloyal Customer   25  Business travel
# 2       110028.0  Female  Sin Cliente Especifico   26  Business travel
# 3        24026.0  Female          Loyal Customer   39  Business travel
# 4       119299.0    Male          Loyal Customer   61  Business travel
# ...          ...     ...                     ...  ...              ...
# 122096   15853.0  Female          Loyal Customer   39  Business travel
# ...

# %% [markdown]
# Verficación

# %%
df_sucio['Checkin service'].isnull().sum()
# Out:
# np.int64(0)

# %%
df_sucio['Checkin service'].unique()
# Out:
# array([4, 1, 3, 5, 2, 0])

# %%
df_sucio['Checkin service'].value_counts()
# Out:
# Checkin service
# 3    29886
# 4    26447
# 5    18787
# 2    11775
# 1    11769
# 0        1
# Name: count, dtype: int64

# %%
df_sucio.columns
# Out:
# Index(['id', 'Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %% [markdown]
# # **20. Columna Inflight service**

# %%
#Datos en la columna
df_sucio['Inflight service'].unique()
# Out:
# array([ 5.,  4.,  3.,  1.,  2., nan,  0.])

# %%
#Datos en la columna
df_sucio['Inflight service'].value_counts()
# Out:
# Inflight service
# 4.0    34627
# 5.0    24701
# 3.0    18484
# 2.0    10386
# 1.0     6470
# 0.0        3
# Name: count, dtype: int64

# %%
#Deteeción de valores nulos
df_sucio['Inflight service'].isnull().sum()
# Out:
# np.int64(3994)

# %%
#Correción de valores nulos cambiandolos por el promedio
df_sucio['Inflight service'] = df_sucio['Inflight service'].fillna(df_sucio['Inflight service'].mean())
# Out:
# /tmp/ipython-input-2359609044.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['Inflight service'] = df_sucio['Inflight service'].fillna(df_sucio['Inflight service'].mean())

# %%
#Conversión de datos a tipo int
df_sucio['Inflight service']=df_sucio['Inflight service'].astype(int)
df_sucio
# Out:
# /tmp/ipython-input-1505792045.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['Inflight service']=df_sucio['Inflight service'].astype(int)
#               id  Gender           Customer Type  Age   Type of Travel  \
# 0        70172.0    Male          Loyal Customer   13  Personal Travel
# 1         5047.0    Male       disloyal Customer   25  Business travel
# 2       110028.0  Female  Sin Cliente Especifico   26  Business travel
# 3        24026.0  Female          Loyal Customer   39  Business travel
# 4       119299.0    Male          Loyal Customer   61  Business travel
# ...          ...     ...                     ...  ...              ...
# 122096   15853.0  Female          Loyal Customer   39  Business travel
# ...

# %% [markdown]
# Verficación

# %%
df_sucio['Inflight service'].isnull().sum()
# Out:
# np.int64(0)

# %%
df_sucio['Inflight service'].unique()
# Out:
# array([5, 4, 3, 1, 2, 0])

# %%
df_sucio['Inflight service'].value_counts()
# Out:
# Inflight service
# 4    34627
# 5    24701
# 3    22478
# 2    10386
# 1     6470
# 0        3
# Name: count, dtype: int64

# %%
df_sucio.columns
# Out:
# Index(['id', 'Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %% [markdown]
# # **21. Columna Cleanliness**

# %%
#Datos en la columna
df_sucio['Cleanliness'].unique()
# Out:
# array([ 5.,  1.,  2.,  3.,  4., nan,  0.])

# %%
#Datos en la columna
df_sucio['Cleanliness'].value_counts()
# Out:
# Cleanliness
# 4.0    24831
# 3.0    22398
# 5.0    20647
# 2.0    14712
# 1.0    12148
# 0.0       10
# Name: count, dtype: int64

# %%
#Deteeción de valores nulos
df_sucio['Cleanliness'].isnull().sum()
# Out:
# np.int64(3919)

# %%
#Correción de valores nulos cambiandolos por el promedio
df_sucio['Cleanliness'] = df_sucio['Cleanliness'].fillna(df_sucio['Cleanliness'].mean())
# Out:
# /tmp/ipython-input-1039820333.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['Cleanliness'] = df_sucio['Cleanliness'].fillna(df_sucio['Cleanliness'].mean())

# %%
#Conversión de datos a tipo int
df_sucio['Cleanliness']=df_sucio['Cleanliness'].astype(int)
df_sucio
# Out:
# /tmp/ipython-input-774376423.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['Cleanliness']=df_sucio['Cleanliness'].astype(int)
#               id  Gender           Customer Type  Age   Type of Travel  \
# 0        70172.0    Male          Loyal Customer   13  Personal Travel
# 1         5047.0    Male       disloyal Customer   25  Business travel
# 2       110028.0  Female  Sin Cliente Especifico   26  Business travel
# 3        24026.0  Female          Loyal Customer   39  Business travel
# 4       119299.0    Male          Loyal Customer   61  Business travel
# ...          ...     ...                     ...  ...              ...
# 122096   15853.0  Female          Loyal Customer   39  Business travel
# ...

# %% [markdown]
# Verficación

# %%
df_sucio['Cleanliness'].isnull().sum()
# Out:
# np.int64(0)

# %%
df_sucio['Cleanliness'].unique()
# Out:
# array([5, 1, 2, 3, 4, 0])

# %%
df_sucio['Cleanliness'].value_counts()
# Out:
# Cleanliness
# 3    26317
# 4    24831
# 5    20647
# 2    14712
# 1    12148
# 0       10
# Name: count, dtype: int64

# %%
df_sucio.columns
# Out:
# Index(['id', 'Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %% [markdown]
# # **22. Columna Departure Delay in Minutes**

# %%
#Cantidad de datos en la columna
df_sucio['Departure Delay in Minutes'].value_counts()
# Out:
# Departure Delay in Minutes
# 0.0      53508
# 1.0       2676
# 2.0       2096
# 3.0       1819
# 4.0       1686
#          ...
# 390.0        1
# 314.0        1
# 343.0        1
# 724.0        1
# 337.0        1
# Name: count, Length: 440, dtype: int64

# %%
#Deteeción de valores nulos
df_sucio['Departure Delay in Minutes'].isnull().sum()
# Out:
# np.int64(4001)

# %%
#Correción de valores nulos cambiandolos por el promedio
df_sucio['Departure Delay in Minutes'] = df_sucio['Departure Delay in Minutes'].fillna(df_sucio['Departure Delay in Minutes'].mean())
# Out:
# /tmp/ipython-input-464995972.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['Departure Delay in Minutes'] = df_sucio['Departure Delay in Minutes'].fillna(df_sucio['Departure Delay in Minutes'].mean())

# %%
#Conversión de datos a tipo int
df_sucio['Departure Delay in Minutes']=df_sucio['Departure Delay in Minutes'].astype(int)
df_sucio
# Out:
# /tmp/ipython-input-1605878272.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['Departure Delay in Minutes']=df_sucio['Departure Delay in Minutes'].astype(int)
#               id  Gender           Customer Type  Age   Type of Travel  \
# 0        70172.0    Male          Loyal Customer   13  Personal Travel
# 1         5047.0    Male       disloyal Customer   25  Business travel
# 2       110028.0  Female  Sin Cliente Especifico   26  Business travel
# 3        24026.0  Female          Loyal Customer   39  Business travel
# 4       119299.0    Male          Loyal Customer   61  Business travel
# ...          ...     ...                     ...  ...              ...
# ...

# %% [markdown]
# Verficación

# %%
df_sucio['Departure Delay in Minutes'].isnull().sum()
# Out:
# np.int64(0)

# %%
df_sucio['Departure Delay in Minutes'].unique()
# Out:
# array([  25,    1,    0,   11,    9,    4,   28,   43,   49,    7,   17,
#          52,   54,   27,   18,   19,    3,  109,   23,   14,    8,   10,
#          51,   39,   13,   30,   64,   20,   45,   44,   31,   81,   35,
#          67,   22,   40,   91,   21,   15,   29,  105,   12,  162,   24,
#         141,    6,   34,    2,   97,   16,   99,   37,   66,   53,   36,
#         209,   60,  149,   26,    5,   59,   62,  113,   38,   83,  176,
#          46,   73,  199,   56,   93,   57,   95,   74,  172,   63,  143,
#          47,  101,  118,   76,  220,   33,   55,  170,  173,  124,  112,
#          94,  243,  128,   92,  270,   90,  110,   50,   71,  315,  158,
#          88,   80,   65,  111,   32,  156,   41,  154,  150,  137,  126,
#         161,   42,  174,  103,  313,  136,  160,  232,  412,   70,   69,
#         185,  114,  135,  147,  235,  391,   84,  138,  102,   85,  196,
#         140,   77,  187,  131,   48,  100,   86,  165,   87,   72,  129,
# ...

# %%
df_sucio['Departure Delay in Minutes'].value_counts()
# Out:
# Departure Delay in Minutes
# 0      53508
# 14      4847
# 1       2676
# 2       2096
# 3       1819
#        ...
# 390        1
# 314        1
# 343        1
# 724        1
# 337        1
# Name: count, Length: 440, dtype: int64

# %% [markdown]
# # **23. Columna Arrival Delay in Minutes**

# %%
#Datos en la columna
df_sucio['Arrival Delay in Minutes'].unique()
# Out:
# array(['18.0', '6.0', '0.0', '9.0', 'bbb', '23.0', '8.0', '35.0', '51.0',
#        '10.0', '5.0', '4.0', '29.0', '44.0', '28.0', '12.0', '120.0',
#        '24.0', '1.0', '20.0', '31.0', '15.0', '48.0', '26.0', nan, '49.0',
#        '2.0', '37.0', '50.0', '3.0', '19.0', '72.0', '11.0', '34.0',
#        '62.0', '27.0', '52.0', '13.0', '82.0', '16.0', '7.0', '122.0',
#        '30.0', '125.0', '17.0', '89.0', '101.0', '14.0', '61.0', '32.0',
#        '33.0', '41.0', '191.0', '138.0', '53.0', '57.0', '65.0', '76.0',
#        '107.0', '92.0', '164.0', '22.0', '40.0', '55.0', '185.0', '63.0',
#        '86.0', '91.0', '100.0', '36.0', '70.0', '139.0', '67.0', '163.0',
#        '21.0', '128.0', '93.0', '121.0', '45.0', '126.0', '56.0', '73.0',
#        '212.0', '88.0', '241.0', '172.0', '175.0', '111.0', '25.0',
#        '42.0', '226.0', '46.0', '131.0', '260.0', '58.0', '75.0', '38.0',
#        '66.0', '39.0', '307.0', '156.0', '74.0', '109.0', '77.0', '155.0',
# ...

# %%
#Cantidad de datos en la columna
df_sucio['Arrival Delay in Minutes'].value_counts()
# Out:
# Arrival Delay in Minutes
# 0.0      52040
# 1.0       1997
# bbb       1892
# 2.0       1854
# 3.0       1760
#          ...
# 271.0        1
# 352.0        1
# 385.0        1
# 705.0        1
# 369.0        1
# Name: count, Length: 444, dtype: int64

# %%
#Deteeción de valores nulos
df_sucio['Arrival Delay in Minutes'].isnull().sum()
# Out:
# np.int64(4247)

# %%
#Corrección de valores atípicos
df_sucio['Arrival Delay in Minutes'] = df_sucio['Arrival Delay in Minutes'].replace('bbb', '1')
# Out:
# /tmp/ipython-input-118553684.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['Arrival Delay in Minutes'] = df_sucio['Arrival Delay in Minutes'].replace('bbb', '1')

# %%
#Correción de valores nulos
df_sucio['Arrival Delay in Minutes'] = df_sucio['Arrival Delay in Minutes'].fillna('1')
# Out:
# /tmp/ipython-input-2029390985.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['Arrival Delay in Minutes'] = df_sucio['Arrival Delay in Minutes'].fillna('1')

# %% [markdown]
# Desde el principio notamos que el tipo de dato en la columna es un object, por lo tanto, debemos convertir esos datos a tipo entero

# %%
#Conversión de datos a tipo int
df_sucio['Arrival Delay in Minutes']=df_sucio['Arrival Delay in Minutes'].astype(float)
df_sucio['Arrival Delay in Minutes']=df_sucio['Arrival Delay in Minutes'].astype(int)
df_sucio
# Out:
# /tmp/ipython-input-2498487195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['Arrival Delay in Minutes']=df_sucio['Arrival Delay in Minutes'].astype(float)
# /tmp/ipython-input-2498487195.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['Arrival Delay in Minutes']=df_sucio['Arrival Delay in Minutes'].astype(int)
#               id  Gender           Customer Type  Age   Type of Travel  \
# 0        70172.0    Male          Loyal Customer   13  Personal Travel
# ...

# %% [markdown]
# Verficación

# %%
df_sucio['Arrival Delay in Minutes'].isnull().sum()
# Out:
# np.int64(0)

# %%
df_sucio['Arrival Delay in Minutes'].unique()
# Out:
# array([  18,    6,    0,    9,    1,   23,    8,   35,   51,   10,    5,
#           4,   29,   44,   28,   12,  120,   24,   20,   31,   15,   48,
#          26,   49,    2,   37,   50,    3,   19,   72,   11,   34,   62,
#          27,   52,   13,   82,   16,    7,  122,   30,  125,   17,   89,
#         101,   14,   61,   32,   33,   41,  191,  138,   53,   57,   65,
#          76,  107,   92,  164,   22,   40,   55,  185,   63,   86,   91,
#         100,   36,   70,  139,   67,  163,   21,  128,   93,  121,   45,
#         126,   56,   73,  212,   88,  241,  172,  175,  111,   25,   42,
#         226,   46,  131,  260,   58,   75,   38,   66,   39,  307,  156,
#          74,  109,   77,  155,   60,  154,   43,  147,  124,  150,  116,
#         171,  105,   84,  165,   94,   83,  336,   59,  219,   87,  459,
#          54,  104,  133,   81,  259,   68,  222,  203,   47,  354,   80,
#         214,   78,   95,   71,  110,   85,  146,  196,  470,  149,  113,
# ...

# %%
df_sucio['Arrival Delay in Minutes'].value_counts()
# Out:
# Arrival Delay in Minutes
# 0      52040
# 1       8136
# 2       1854
# 3       1760
# 4       1699
#        ...
# 271        1
# 352        1
# 385        1
# 705        1
# 369        1
# Name: count, Length: 443, dtype: int64

# %%
df_sucio.columns
# Out:
# Index(['id', 'Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %% [markdown]
# # **24. Columna satisfaction**

# %%
#Datos en la columna
df_sucio['satisfaction'].unique()
# Out:
# array(['neutral or dissatisfied', nan, 'satisfied', 'bbb'], dtype=object)

# %%
#Cantidad de datos en la columna
df_sucio['satisfaction'].value_counts()
# Out:
# satisfaction
# neutral or dissatisfied    52529
# satisfied                  40263
# bbb                         1888
# Name: count, dtype: int64

# %%
#Correción de datos
df_sucio['satisfaction'] = df_sucio['satisfaction'].replace('neutral or dissatisfied', 'dissatisfied')
# Out:
# /tmp/ipython-input-3786809346.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['satisfaction'] = df_sucio['satisfaction'].replace('neutral or dissatisfied', 'dissatisfied')

# %%
#Correción de valores atípicos
df_sucio['satisfaction'] = df_sucio['satisfaction'].replace('bbb', 'neutral')
# Out:
# /tmp/ipython-input-3929596433.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['satisfaction'] = df_sucio['satisfaction'].replace('bbb', 'neutral')

# %%
#Deteeción de valores nulos
df_sucio['satisfaction'].isnull().sum()
# Out:
# np.int64(3985)

# %%
#Correción de valores nulos
df_sucio['satisfaction'] = df_sucio['satisfaction'].fillna('neutral')
# Out:
# /tmp/ipython-input-1226860260.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sucio['satisfaction'] = df_sucio['satisfaction'].fillna('neutral')

# %% [markdown]
# Verficación

# %%
df_sucio['satisfaction'].isnull().sum()
# Out:
# np.int64(0)

# %%
df_sucio['satisfaction'].unique()
# Out:
# array(['dissatisfied', 'neutral', 'satisfied'], dtype=object)

# %%
df_sucio['satisfaction'].value_counts()
# Out:
# satisfaction
# dissatisfied    52529
# satisfied       40263
# neutral          5873
# Name: count, dtype: int64

# %% [markdown]
# # **Cambio de Nombre a las columnas**

# %%
df_sucio.columns
# Out:
# Index(['id', 'Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
# Cambiar nombres de columnas
df_sucio = df_sucio.rename(columns={
    'Gender': 'Genero',
    'Customer Type': 'Tipo de Cliente',
    'Age': 'Edad',
    'Type of Travel': 'Tipo de Viaje',
    'Class': 'Clase',
    'Flight Distance': 'Distancia de Vuelo',
    'Inflight wifi service': 'Servicio de Wifi',
    'Departure/Arrival time convenient': 'Tiempo de Llegada/Salida Conveniente',
    'Ease of Online booking': 'Facilidad de Reservacion en Linea',
    'Gate location': 'Ubicacion de Puerta',
    'Food and drink': 'Comida y Bebida',
    'Online boarding': 'Abordaje en Linea',
    'Seat comfort': 'Comodidad de Asiento',
    'Inflight entertainment': 'Entretenimiento en Vuelo',
    'On-board service': 'Servicio en Mesa',
    'Leg room service': 'Espacio del Asiento',
    'Baggage handling': 'Servicio de Equipaje',
    'Checkin service': 'Servicio de Checkin',
    'Inflight service': 'Servicio de Vuelo',
    'Cleanliness': 'Limpieza',
    'Departure Delay in Minutes': 'Retraso de Salida',
    'Arrival Delay in Minutes': 'Retraso de Llegada',
    'satisfaction': 'Satisfaccion'
})

df_sucio
# Out:
#               id  Genero         Tipo de Cliente  Edad    Tipo de Viaje  \
# 0        70172.0    Male          Loyal Customer    13  Personal Travel
# 1         5047.0    Male       disloyal Customer    25  Business travel
# 2       110028.0  Female  Sin Cliente Especifico    26  Business travel
# 3        24026.0  Female          Loyal Customer    39  Business travel
# 4       119299.0    Male          Loyal Customer    61  Business travel
# ...          ...     ...                     ...   ...              ...
# 122096   15853.0  Female          Loyal Customer    39  Business travel
# 122128   83437.0  Female       disloyal Customer    23  Business travel
# 122129  104401.0    Male          Loyal Customer    60  Business travel
# 122140  114393.0  Female          Loyal Customer    44  Business travel
# 122165   55896.0  Female       disloyal Customer    48  Business travel
#
#             Clase  Distancia de Vuelo  Servicio de Wifi  \
# ...

# %% [markdown]
# # **Traducción para algunos datos**

# %%
#Columna Genero
df_sucio['Genero'] = df_sucio['Genero'].replace({
    'Female': 'Femenino',
    'Male': 'Masculino'
})

#Columna Tipo de Cliebre
df_sucio['Tipo de Cliente'] = df_sucio['Tipo de Cliente'].replace({
    'Loyal Customer': 'Cliente Leal',
    'disloyal Customer': 'Cliente Desleal'
})

#Columna Tipo de Viaje
df_sucio['Tipo de Viaje'] = df_sucio['Tipo de Viaje'].replace({
    'Business travel': 'Viaje de Negocios',
    'Personal Travel': 'Viaje Personal'
})

#Columna Clase
df_sucio['Clase'] = df_sucio['Clase'].replace({
    'Business': 'Ejecutiva',
    'Eco': 'Económica',
    'Eco Plus': 'Económica Plus'
})

#Columna Satisfaccion
df_sucio['Satisfaccion'] = df_sucio['Satisfaccion'].replace({
    'satisfied': 'Satisfecho',
    'dissatisfied': 'Insatisfecho'
})

df_sucio
# Out:
#               id     Genero         Tipo de Cliente  Edad      Tipo de Viaje  \
# 0        70172.0  Masculino            Cliente Leal    13     Viaje Personal
# 1         5047.0  Masculino         Cliente Desleal    25  Viaje de Negocios
# 2       110028.0   Femenino  Sin Cliente Especifico    26  Viaje de Negocios
# 3        24026.0   Femenino            Cliente Leal    39  Viaje de Negocios
# 4       119299.0  Masculino            Cliente Leal    61  Viaje de Negocios
# ...          ...        ...                     ...   ...                ...
# 122096   15853.0   Femenino            Cliente Leal    39  Viaje de Negocios
# 122128   83437.0   Femenino         Cliente Desleal    23  Viaje de Negocios
# 122129  104401.0  Masculino            Cliente Leal    60  Viaje de Negocios
# 122140  114393.0   Femenino            Cliente Leal    44  Viaje de Negocios
# 122165   55896.0   Femenino         Cliente Desleal    48  Viaje de Negocios
#
# ...

# %% [markdown]
# **Pasamos todo a un df limpio**

# %%
df_limpio = df_sucio.copy()
df_limpio
# Out:
#               id     Genero         Tipo de Cliente  Edad      Tipo de Viaje  \
# 0        70172.0  Masculino            Cliente Leal    13     Viaje Personal
# 1         5047.0  Masculino         Cliente Desleal    25  Viaje de Negocios
# 2       110028.0   Femenino  Sin Cliente Especifico    26  Viaje de Negocios
# 3        24026.0   Femenino            Cliente Leal    39  Viaje de Negocios
# 4       119299.0  Masculino            Cliente Leal    61  Viaje de Negocios
# ...          ...        ...                     ...   ...                ...
# 122096   15853.0   Femenino            Cliente Leal    39  Viaje de Negocios
# 122128   83437.0   Femenino         Cliente Desleal    23  Viaje de Negocios
# 122129  104401.0  Masculino            Cliente Leal    60  Viaje de Negocios
# 122140  114393.0   Femenino            Cliente Leal    44  Viaje de Negocios
# 122165   55896.0   Femenino         Cliente Desleal    48  Viaje de Negocios
#
# ...

# %% [markdown]
# # ***Verificación de Limpieza para toda la base de datos***

# %% [markdown]
# Una vez terminada la limpieza se rectifica que la información se encuentre de manera adecuada, sin distorsiones o con algun valor que se pudo omitir durante el proceso, verificando valores nulos, valores duplicados, tipo de datos, y traducciones

# %%
#Verificación del tipo de dato en cada columna
df_limpio.dtypes
# Out:
# id                                      object
# Genero                                  object
# Tipo de Cliente                         object
# Edad                                     int64
# Tipo de Viaje                           object
# Clase                                   object
# Distancia de Vuelo                       int64
# Servicio de Wifi                         int64
# Tiempo de Llegada/Salida Conveniente     int64
# Facilidad de Reservacion en Linea        int64
# Ubicacion de Puerta                      int64
# Comida y Bebida                          int64
# Abordaje en Linea                        int64
# Comodidad de Asiento                     int64
# Entretenimiento en Vuelo                 int64
# Servicio en Mesa                         int64
# Espacio del Asiento                      int64
# Servicio de Equipaje                     int64
# Servicio de Checkin                      int64
# Servicio de Vuelo                        int64
# ...

# %%
df_limpio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 98665 entries, 0 to 122165
# Data columns (total 24 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   id                                    98665 non-null  object
#  1   Genero                                98665 non-null  object
#  2   Tipo de Cliente                       98665 non-null  object
#  3   Edad                                  98665 non-null  int64
#  4   Tipo de Viaje                         98665 non-null  object
#  5   Clase                                 98665 non-null  object
#  6   Distancia de Vuelo                    98665 non-null  int64
#  7   Servicio de Wifi                      98665 non-null  int64
#  8   Tiempo de Llegada/Salida Conveniente  98665 non-null  int64
#  9   Facilidad de Reservacion en Linea     98665 non-null  int64
#  10  Ubicacion de Puerta                   98665 non-null  int64
# ...

# %%
#Verificacion de valores nulos
df_limpio.isnull().sum()
# Out:
# id                                      0
# Genero                                  0
# Tipo de Cliente                         0
# Edad                                    0
# Tipo de Viaje                           0
# Clase                                   0
# Distancia de Vuelo                      0
# Servicio de Wifi                        0
# Tiempo de Llegada/Salida Conveniente    0
# Facilidad de Reservacion en Linea       0
# Ubicacion de Puerta                     0
# Comida y Bebida                         0
# Abordaje en Linea                       0
# Comodidad de Asiento                    0
# Entretenimiento en Vuelo                0
# Servicio en Mesa                        0
# Espacio del Asiento                     0
# Servicio de Equipaje                    0
# Servicio de Checkin                     0
# Servicio de Vuelo                       0
# Limpieza                                0
# Retraso de Salida                       0
# ...

# %%
#Verificación de datos atípicos con un ciclo for
#Ciclo for para detectar valores atípicos (por ejemplo texto)
lista_col=df_limpio.columns
for i in lista_col:
    print(f"En la columna {i} los bbb son: {df_sucio[df_sucio[i] == 'bbb'].shape[0]}")
# Out:
# En la columna id los bbb son: 0
# En la columna Genero los bbb son: 0
# En la columna Tipo de Cliente los bbb son: 0
# En la columna Edad los bbb son: 0
# En la columna Tipo de Viaje los bbb son: 0
# En la columna Clase los bbb son: 0
# En la columna Distancia de Vuelo los bbb son: 0
# En la columna Servicio de Wifi los bbb son: 0
# En la columna Tiempo de Llegada/Salida Conveniente los bbb son: 0
# En la columna Facilidad de Reservacion en Linea los bbb son: 0
# En la columna Ubicacion de Puerta los bbb son: 0
# En la columna Comida y Bebida los bbb son: 0
# En la columna Abordaje en Linea los bbb son: 0
# En la columna Comodidad de Asiento los bbb son: 0
# En la columna Entretenimiento en Vuelo los bbb son: 0
# En la columna Servicio en Mesa los bbb son: 0
# En la columna Espacio del Asiento los bbb son: 0
# En la columna Servicio de Equipaje los bbb son: 0
# En la columna Servicio de Checkin los bbb son: 0
# En la columna Servicio de Vuelo los bbb son: 0
# ...

# %%
#Verificación de duplicados
df_limpio.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Guardar la base de datos en un archivo csv
df_limpio.to_csv('df_limpio.csv', index=False)
